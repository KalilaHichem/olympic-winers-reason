# %%
# import liberies
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
# the data was colected in google sheet
# Now we need to read in the data
df = pd.read_csv(r'C:\Users\21378\Downloads\olympic.csv')

# %%
#tack a look at the data
df.head()
# Out:
#    Rank    Team/NOC  Gold  Silver  Bronze  Total  Rank by Total  population  \
# 0    72   Argentina     0       1       2      3             60    45376763
# 1    69     Armenia     0       2       2      4             47     2963234
# 2     6   Australia    17       7      22     46              6    25687041
# 3    53     Austria     1       1       5      7             33     8917205
# 4    67  Azerbaijan     0       3       4      7             33    10110116
#
#             gdp  hapiness
# 0  3.830670e+11    2.5669
# 1  1.264546e+10    4.6768
# 2  1.330901e+12    7.2228
# 3  4.289654e+11    7.2942
# 4  4.261000e+10    5.1648

# %%
#finding data type of each column
print(df.dtypes)
# Out:
# Rank               int64
# Team/NOC          object
# Gold               int64
# Silver             int64
# Bronze             int64
# Total              int64
# Rank by Total      int64
# population         int64
# gdp              float64
# hapiness         float64
# dtype: object

# %%
#totale medaile vs population
sns.regplot(x="Total", y="population", data=df, scatter_kws={"color":"black"} ,line_kws={"color": "red"})
# Out:
# <AxesSubplot:xlabel='Total', ylabel='population'>

# %%
#totale medaile vs gdp
sns.regplot(x="Total", y="gdp", data=df, scatter_kws={"color":"red"} ,line_kws={"color": "blue"})
# Out:
# <AxesSubplot:xlabel='Total', ylabel='gdp'>

# %%
#totale medaile vs hapiness score
sns.regplot(x="Total", y="hapiness", data=df, scatter_kws={"color":"red"} ,line_kws={"color": "green"})
# Out:
# <AxesSubplot:xlabel='Total', ylabel='hapiness'>
